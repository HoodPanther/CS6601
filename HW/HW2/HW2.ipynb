# %% [markdown]
# # Assignment 2: Gaussian Mixture Models

# %% [markdown]
# ## Author: Ruffin White

# %%
import Image
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.cm as cm
import random
from sklearn import cluster
EPS = np.finfo(float).eps
from sklearn.base import BaseEstimator
from scipy.misc import logsumexp

# %%
image = Image.open("party_spock.png")
im = image.load()
im = np.asarray(image)
print image.format, image.size, image.mode
# Out:
# PNG (700, 526) L

# %%
plt.imshow(im , cmap = cm.Greys_r)
plt.show()

# %%
def kMeans(im, n):
    X = im.reshape((-1, 1)) 
    k_means = cluster.KMeans(n)
    k_means.fit(X) 
    
    values = k_means.cluster_centers_.squeeze()
    labels = k_means.labels_
    
    im_compressed = np.choose(labels, values)
    im_compressed.shape = im.shape
    return im_compressed, values

# %%
n = 8
im2, values = kMeans(im, n)

# %%
plt.imshow(im2 , cmap = cm.Greys_r)
plt.show()
print 'values', values
# Out:
# values [  29.01538877  185.60581451   88.04930424  243.42228591  122.47843291
#     6.04363723   56.34275309  156.17002606]

# %%
class GMM(BaseEstimator):
    def __init__(self, means_, covars_, n_components=1, thresh=1e-2, n_iter=100, n_init=1):
        self.means_ = means_
        self.covars_ = covars_
        self.n_components = n_components
        self.thresh = thresh
        self.n_iter = n_iter
        self.n_init = n_init
        self.weights_ = np.ones(self.n_components) / self.n_components
        self.converged_ = False
        
    def eval(self, X):
        lpr = (_log_multivariate_normal_density_full(X, self.means_, self.covars_) + np.log(self.weights_))
        logprob = logsumexp(lpr, axis=1)
        responsibilities = np.exp(lpr - logprob[:, np.newaxis])
        return logprob, responsibilities
    
    def fit(self, X):
        ## initialization step
        X = np.asarray(X, dtype=np.float)
        max_log_prob = -np.infty

        for _ in range(self.n_init):

            if not hasattr(self, 'weights_'):
                self.weights_ = np.tile(1.0 / self.n_components, self.n_components)

            # EM algorithms
            log_likelihood = []
            # reset self.converged_ to False
            self.converged_ = False
            for i in xrange(self.n_iter):
                # Expectation step
                curr_log_likelihood, responsibilities = self.eval(X)
                log_likelihood.append(curr_log_likelihood.sum())

                # Check for convergence.
                if i > 0 and abs(log_likelihood[-1] - log_likelihood[-2]) < self.thresh:
                    self.converged_ = True
                    break

                # Maximization step
                self._do_mstep(X, responsibilities, 'wmc')

            # if the results are better, keep it
            if self.n_iter:
                if log_likelihood[-1] > max_log_prob:
                    max_log_prob = log_likelihood[-1]
                    best_params = {'weights': self.weights_,
                                   'means': self.means_,
                                   'covars': self.covars_}
                    
        # self.n_iter == 0 occurs when using GMM within HMM
        if self.n_iter:
            self.covars_ = best_params['covars']
            self.means_ = best_params['means']
            self.weights_ = best_params['weights']
        return self

    def _do_mstep(self, X, responsibilities, params, min_covar=0):
        """ Perform the Mstep of the EM algorithm and return the class weihgts.
        """
        weights = responsibilities.sum(axis=0)
        weighted_X_sum = np.dot(responsibilities.T, X)
        inverse_weights = 1.0 / (weights[:, np.newaxis] + 10 * EPS)

        if 'w' in params:
            self.weights_ = (weights / (weights.sum() + 10 * EPS) + EPS)
        if 'm' in params:
            self.means_ = weighted_X_sum * inverse_weights
        if 'c' in params:
            self.covars_ = _covar_mstep_full( self, X, responsibilities, weighted_X_sum, inverse_weights,min_covar)
        return weights
    
    def score(self, X):
        logprob, _ = self.eval(X)
        return logprob
    
    def compress(self, im):
        X = im.reshape((-1, 1))

        self.fit(X)
        curr_log_likelihood, responsibilities = self.eval(X)
        
        values = self.means_
        labels = responsibilities.argmax(axis=1)
        
        im_compressed = np.choose(labels, values)
        im_compressed.shape = im.shape
        return im_compressed
    
    
def _log_multivariate_normal_density_full(X, means, covars, min_covar=1.e-7):
    """Log probability for full covariance matrices.
    """
    from scipy import linalg
    import itertools
    
    solve_triangular = linalg.solve_triangular
        
    n_samples, n_dim = X.shape
    nmix = len(means)
    log_prob = np.empty((n_samples, nmix))
    for c, (mu, cv) in enumerate(itertools.izip(means, covars)):
        try:
            cv_chol = linalg.cholesky(cv, lower=True)
        except linalg.LinAlgError:
            # The model is most probabily stuck in a component with too
            # few observations, we need to reinitialize this components
            cv_chol = linalg.cholesky(cv + min_covar * np.eye(n_dim), lower=True)
        cv_log_det = 2 * np.sum(np.log(np.diagonal(cv_chol)))
        cv_sol = solve_triangular(cv_chol, (X - mu).T, lower=True).T
        log_prob[:, c] = - .5 * (np.sum(cv_sol ** 2, axis=1) + n_dim * np.log(2 * np.pi) + cv_log_det)

    return log_prob
    
    
def _covar_mstep_full(gmm, X, responsibilities, weighted_X_sum, norm, min_covar):
    """Performing the covariance M step for full cases"""
    # Eq. 12 from K. Murphy, "Fitting a Conditional Linear Gaussian
    # Distribution"
    n_features = X.shape[1]
    cv = np.empty((gmm.n_components, n_features, n_features))
    for c in xrange(gmm.n_components):
        post = responsibilities[:, c]
        # Underflow Errors in doing post * X.T are  not important
        np.seterr(under='ignore')
        avg_cv = np.dot(post * X.T, X) / (post.sum() + 10 * EPS)
        mu = gmm.means_[c][np.newaxis]
        cv[c] = (avg_cv - np.dot(mu.T, mu) + min_covar * np.eye(n_features))
    return cv

# %%
X = im.reshape((-1, 1))
tied_cv = np.cov(X.T)
cv = np.tile(tied_cv, (3, 1, 1))

_gmm = GMM(values,cv,n)
_gmm.fit(X)
# Out:
# GMM(covars_=array([[[    2.93347]],
#
#        [[   16.36421]],
#
#        [[   22.15641]],
#
#        [[  586.14636]],
#
#        [[ 1500.59053]],
#
#        [[  176.34118]],
#
#        [[ 1500.07099]],
#
#        [[  535.14046]]]),
#   means_=array([[   2.50685],
#        [ 249.86934],
#        [   9.64093],
#        [  71.88913],
#        [ 160.5982 ],
#        [  30.98531],
#        [ 160.57358],
#        [  69.89307]]),
#   n_components=8, n_init=1, n_iter=100, thresh=0.01)

# %%
print 'means', _gmm.means_
print 'covars', _gmm.covars_
print 'weights', _gmm.weights_
# Out:
# means [[   2.50684588]
#  [ 249.86934388]
#  [   9.64093385]
#  [  71.88913061]
#  [ 160.59819732]
#  [  30.98530893]
#  [ 160.5735824 ]
#  [  69.89306551]]
# covars [[[    2.93347041]]
#
#  [[   16.36421173]]
#
#  [[   22.15640522]]
#
#  [[  586.14636296]]
#
#  [[ 1500.59052624]]
#
#  [[  176.34117907]]
#
#  [[ 1500.07099429]]
#
#  [[  535.14046347]]]
# weights [ 0.16024045  0.05793567  0.15186403  0.08916559  0.1294762   0.18894262
#   0.12944733  0.09292812]

# %%
im3 = _gmm.compress(im)

# %%
plt.imshow(im3 , cmap = cm.Greys_r)
plt.show()

# %%
fig = pyplot.figure(figsize=(24,12), dpi=300)
hist = plt.hist(im.flatten(), bins=256, fc='r', ec='r',range=(0,255))

# %%
fig = pyplot.figure(figsize=(24,12), dpi=300)
hist = plt.hist(im3.flatten(), bins=256, fc='r', ec='r', range=(0,255))
