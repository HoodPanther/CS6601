# %% [markdown]
# # Assignment 2: Gaussian Mixture Models

# %% [markdown]
# ## Author: Ruffin White

# %%
import Image
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.cm as cm

# %%
im = Image.open("party_spock.png")
image = im.load()
print im.format, im.size, im.mode
# Out:
# PNG (700, 526) L

# %%
plt.imshow(np.asarray(im), cmap = cm.Greys_r)
plt.show()
